# %%
# add key and value to dictionary

mydict = {"ten": 10, "twenty": 20}
mydict["thirty"] = 30
print(mydict)
# Out:
# {'ten': 10, 'twenty': 20, 'thirty': 30}

# %%
# concatenate dictionaries into new one

dict1 = {1: 1, 2: 2}
dict2 = {3: 3, 4: 4}
dict3 = {"hello": "world", "bye": "bye"}

new_dict.update(dict1)
new_dict.update(dict2)
new_dict.update(dict3)

print("New dictionary: ", new_dict)
# Out:
# New dictionary:  {1: 1, 2: 2, 3: 3, 4: 4, 'hello': 'world', 'bye': 'bye'}
